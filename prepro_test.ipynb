# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn import preprocessing

# %%
df=pd.read_csv('test_set_features.csv')

# %%
df.head()
# Out:
#    respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0          26707          2.0            2.0                        0.0
# 1          26708          1.0            1.0                        0.0
# 2          26709          2.0            2.0                        0.0
# 3          26710          1.0            1.0                        0.0
# 4          26711          3.0            1.0                        1.0
#
#    behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 0                   1.0                   0.0                    1.0
# 1                   0.0                   0.0                    0.0
# 2                   0.0                   1.0                    1.0
# 3                   0.0                   0.0                    0.0
# 4                   1.0                   0.0                    1.0
#
#    behavioral_large_gatherings  behavioral_outside_home  \
# 0                          1.0                      0.0
# ...

# %%
df.columns
# Out:
# Index(['respondent_id', 'xyz_concern', 'xyz_knowledge',
#        'behavioral_antiviral_meds', 'behavioral_avoidance',
#        'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk',
#        'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
#        'education', 'race', 'sex', 'income_poverty', 'marital_status',
#        'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa',
#        'household_adults', 'household_children', 'employment_industry',
#        'employment_occupation'],
#       dtype='object')

# %%
empty_rows = df.isnull().any(axis=1)

# %%
df[empty_rows]
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 6              26713          2.0            2.0                        0.0
# 7              26714          2.0            1.0                        0.0
# 8              26715          1.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26699          53406          1.0            2.0                        0.0
# 26703          53410          1.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
df=df.drop(['employment_industry'],axis=1)
df=df.drop(['employment_occupation'],axis=1)
df=df.drop(['hhs_geo_region'],axis=1)

# %%
empty_rows = df.isnull().any(axis=1)
empty_rows
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 26703     True
# 26704    False
# 26705    False
# 26706     True
# 26707     True
# Length: 26708, dtype: bool

# %%
df[empty_rows]
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 2              26709          2.0            2.0                        0.0
# 6              26713          2.0            2.0                        0.0
# 8              26715          1.0            1.0                        0.0
# 10             26717          3.0            1.0                        0.0
# 13             26720          1.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26697          53404          3.0            1.0                        0.0
# 26699          53406          1.0            2.0                        0.0
# 26703          53410          1.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.fillna(-1, inplace=True)

# %%
le1 = LabelEncoder()
le2 = LabelEncoder()
le3 = LabelEncoder()
le4 = LabelEncoder()
le5 = LabelEncoder()
le6 = LabelEncoder()
le7 = LabelEncoder()
le8 = LabelEncoder()
le9 = LabelEncoder()

# Fit the LabelEncoders and transform the columns
df['age_group'] = le1.fit_transform(df['age_group'].astype(str).fillna(''))
df['education'] = le2.fit_transform(df['education'].astype(str).fillna(''))
df['race'] = le3.fit_transform(df['race'].astype(str).fillna(''))
df['sex'] = le4.fit_transform(df['sex'].astype(str).fillna(''))
df['income_poverty'] = le5.fit_transform(df['income_poverty'].astype(str).fillna(''))
df['marital_status'] = le6.fit_transform(df['marital_status'].astype(str).fillna(''))
df['rent_or_own'] = le7.fit_transform(df['rent_or_own'].astype(str).fillna(''))
df['employment_status'] = le8.fit_transform(df['employment_status'].astype(str).fillna(''))
df['census_msa'] = le9.fit_transform(df['census_msa'].astype(str).fillna(''))

# %%
df.to_csv("test.csv",index=False)
